# %%
library(here)
library(Matrix)
library(tidyverse)
library(Seurat)
library(scico)
library(scales)
library(reticulate)
library(repr)
library(future)
options(future.globals.maxSize = 100000 * 1024^2)

# %%
shoots_seu = readRDS(file = "../data/shoots/shoots.Rds")

# %%
DimPlot(shoots_seu, reduction = "umap", label = FALSE, pt.size = 1.5)
# Out:
# plot without title
